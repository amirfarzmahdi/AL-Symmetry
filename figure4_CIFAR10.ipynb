# %%
# CIFAR10 dataset, digit recognition
import torch
import torchvision
from torchvision import transforms, utils
import numpy as np
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from matplotlib import rcParams
import matplotlib as style
import random
import pickle
import scipy
import scipy.io as sio
from scipy.stats import pearsonr
import pickle
from PIL import Image
from scipy import stats

# %%
# set random seed
np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# %%
# check available GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# cuda:0
# NVIDIA GeForce RTX 2080 Ti
# /home/flab/anaconda3/lib/python3.8/site-packages/torch/cuda/__init__.py:122: UserWarning:
#     Found GPU1 NVIDIA GeForce GT 710 which is of cuda capability 3.5.
#     PyTorch no longer supports this GPU because it is too old.
#     The minimum cuda capability supported by this library is 3.7.
#
#   warnings.warn(old_gpu_warn % (d, name, major, minor, min_arch // 10, min_arch % 10))

# %%
# main setting
batch_size = 256
n_epochs = 250
classes = ['plane','car','bird','cat','deer','dog','frog','horse','ship','truck']

# images
ncatg = 9
nview = 9
nexemplar = 25
num_imgs = nexemplar * nview * ncatg # number of images
img_size = 32
nchannel = 3
net_name = 'CIFAR10'

PATH = f"{net_name}_net.pt"
msvt_dir = 'msvt/'

# %%
# our stimulus set
imgs_mat = scipy.io.loadmat('imgs.mat')
imgs = list(imgs_mat.values())
imgs = imgs[3].T
imgs = np.reshape(imgs,(num_imgs,))

# %%
# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261]),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261]),
])

trainset = torchvision.datasets.CIFAR10(root='./data',train=True,download=True,transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data',train=False,download=True,transform=transform_test)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Calculate the lengths for the train and validation sets
train_len = int(0.9 * len(trainset))
val_len = len(trainset) - train_len

# Split the dataset into train and validation sets

train_dataset, val_dataset = torch.utils.data.random_split(trainset, [train_len, val_len])

# Create data loaders for train and validation sets
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
validation_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)

data_loaders = {"train": train_loader, "val": validation_loader}
data_lengths = {"train":train_len, "val": val_len}

# %%
#show example images
fig = plt.figure(figsize=(10,15))

def imshow(img):
    img = img/2+0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg,(1, 2, 0)))
    plt.show()

dataiter = iter(train_loader)
images, labels =  dataiter.next()

imshow(torchvision.utils.make_grid(images))
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   cat horse  ship   car  ship   dog  bird plane horse  bird plane  bird  ship horse truck   car  deer plane  ship  ship plane  deer   dog truck horse  ship  frog   car  bird  deer   dog  bird   car horse  ship  deer truck plane  bird  bird truck truck   cat plane  frog   dog   dog   dog  deer  ship   dog horse   dog horse plane   car   cat  frog   car  deer  ship  frog  frog   cat   dog  frog  ship   car   dog truck   dog  frog   car   dog  ship plane truck   cat   car horse truck horse   dog truck   car  deer   dog  bird   dog  bird  bird   dog  frog horse   dog   car truck  frog   dog   cat   car truck  frog horse truck plane  deer  bird   dog  deer plane horse  ship horse  ship  frog plane   car plane  bird  frog  ship  ship   car  ship  frog truck   cat  frog  frog horse  deer  ship  ship horse  bird  deer   dog  bird  frog   dog truck truck truck  ship plane   cat  bird plane horse  bird   dog truck   cat truck   cat horse   car   dog   cat   car  deer plane   cat  ship  frog truck   cat   cat horse   car truck   dog truck  deer   dog  ship horse  frog   dog horse   car  ship   car  deer  frog  ship  deer horse plane plane  frog   dog  deer horse  frog  bird  frog  bird   car  deer   car truck  frog   cat plane   dog  deer   dog   cat horse  bird truck horse   car  bird   car truck   car horse horse truck  ship   cat truck  deer  bird  ship   cat   car   cat horse plane  deer  ship   cat truck  bird  frog   car  ship   cat truck   cat   dog horse  frog  ship plane  bird   dog  frog  frog   dog  ship  deer

# %%
# create CNN network
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.conv1_1 = nn.Conv2d(in_channels=3,out_channels=32,kernel_size=3)
        self.conv1_2 = nn.Conv2d(in_channels=32,out_channels=32,kernel_size=3)
        self.pool = nn.MaxPool2d(2,2)
        self.conv2_1 = nn.Conv2d(in_channels=32,out_channels=64,kernel_size=3)
        self.conv2_2 = nn.Conv2d(in_channels=64,out_channels=128,kernel_size=3)
        self.fc1 = nn.Linear(128*5*5,256)
        self.fc2 = nn.Linear(256,256)
        self.fc3 = nn.Linear(256,10)
        self.drop = nn.Dropout(p=0.5)
        self.batch1 = nn.BatchNorm2d(32)
        self.batch2 = nn.BatchNorm2d(64)
    
    def forward(self,x):
        x = F.relu(self.conv1_1(x))
        x = self.batch1(x)
        x = F.relu(self.conv1_2(x))
        x = self.pool(x)
        x = F.relu(self.conv2_1(x))
        x = self.batch2(x)
        x = F.relu(self.conv2_2(x))
        x = self.pool(x)
        x = x.view(-1,128*5*5)
        x = F.relu(self.fc1(x))
        x = self.drop(x)
        x = F.relu(self.fc2(x))
        x = self.drop(x)
        x = self.fc3(x)
        return x

net = Net()
net.to(device)
# Out:
# Net(
#   (conv1_1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv1_2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv2_2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=3200, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
#   (drop): Dropout(p=0.5, inplace=False)
#   (batch1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0):
        """
        Args:
        patience (int): How long to wait after last time validation loss improved.
        Default: 7
        verbose (bool): If True, prints a message for each validation loss improvement. 
        Default: False
        delta (float): Minimum change in the monitored quantity to qualify as an improvement.
        Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None 
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). diff: {val_loss - self.val_loss_min}  Saving model ...')
        torch.save(model.state_dict(), f'{net_name}_net.pt')
        self.val_loss_min = val_loss

# %%
# Initialize the early_stopping object
early_stopping = EarlyStopping(patience=200, verbose=True)

# %%
# loss function
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = 0.001, momentum=0.9, weight_decay=0)

# %%
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)

# %%
train_loss, train_acc, val_loss, val_acc = [], [], [], []

# training & validating
for epoch in range(n_epochs):
    print('Epoch {}/{}'.format(epoch, n_epochs - 1))
    print('-' * 10)

    # Each epoch has a training and validation phase
    for phase in ['train', 'val']:
        if phase == 'train':
            net.train()  # Set model to training mode
        else:
            net.eval()  # Set model to evaluate mode

        running_loss = 0.0
        correct = 0
        total = 0

        # Iterate over data.
        for data in data_loaders[phase]:
            inputs, labels = data[0].to(device), data[1].to(device)

            # zero the parameter (weight) gradients
            optimizer.zero_grad()

            # forward
            # track history if only in train
            with torch.set_grad_enabled(phase == 'train'):
                outputs = net(inputs)
                loss = criterion(outputs, labels)
                _, predicted = torch.max(outputs.data, 1)

                # backward + optimize only if in training phase
                if phase == 'train':
                    loss.backward()
                    optimizer.step()

            # statistics
            running_loss += loss.item() * inputs.size(0)  # Multiply by batch size
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_loss = running_loss / data_lengths[phase]
        accuracy = (100 * correct / total)

        if phase == 'train':
            train_loss.append(epoch_loss)
            train_acc.append(accuracy)
        else:
            val_loss.append(epoch_loss)
            val_acc.append(accuracy)
            # Early_stopping needs the validation loss to check if it has decreased,
            # and if it has, it will then save the current model checkpoint
            early_stopping(epoch_loss, net)
            if early_stopping.early_stop:
                print("Early stopping")
                break  # Break from the loop

        print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, accuracy))

    # Call scheduler.step() after each epoch when using StepLR
    scheduler.step()

    if early_stopping.early_stop:
        print("Early stopping")
        break
# Out:
# Epoch 0/249
# ----------
# train Loss: 2.2817 Acc: 13.1622
# Validation loss decreased (inf --> 2.214192). diff: -inf  Saving model ...
# val Loss: 2.2142 Acc: 21.3400
# Epoch 1/249
# ----------
# train Loss: 2.0923 Acc: 20.9800
# Validation loss decreased (2.214192 --> 1.889225). diff: -0.3249667814254762  Saving model ...
# val Loss: 1.8892 Acc: 32.1800
# Epoch 2/249
# ----------
# train Loss: 1.8823 Acc: 26.3933
# Validation loss decreased (1.889225 --> 1.752028). diff: -0.13719719848632805  Saving model ...
# val Loss: 1.7520 Acc: 35.6200
# Epoch 3/249
# ----------
# train Loss: 1.7777 Acc: 31.5578
# Validation loss decreased (1.752028 --> 1.655913). diff: -0.09611464843749995  Saving model ...
# val Loss: 1.6559 Acc: 38.9200
# Epoch 4/249
# ----------
# train Loss: 1.6903 Acc: 35.2467
# Validation loss decreased (1.655913 --> 1.575114). diff: -0.08079908847808848  Saving model ...
# val Loss: 1.5751 Acc: 41.7200
# Epoch 5/249
# ----------
# train Loss: 1.6275 Acc: 38.1489
# Validation loss decreased (1.575114 --> 1.536060). diff: -0.039054459571838285  Saving model ...
# val Loss: 1.5361 Acc: 43.6400
# Epoch 6/249
# ----------
# train Loss: 1.5707 Acc: 40.6311
# Validation loss decreased (1.536060 --> 1.458453). diff: -0.07760661678314218  Saving model ...
# val Loss: 1.4585 Acc: 46.5600
# Epoch 7/249
# ----------
# train Loss: 1.5145 Acc: 43.1200
# Validation loss decreased (1.458453 --> 1.412202). diff: -0.0462510339736939  Saving model ...
# val Loss: 1.4122 Acc: 48.4600
# Epoch 8/249
# ----------
# train Loss: 1.4680 Acc: 45.5844
# Validation loss decreased (1.412202 --> 1.336873). diff: -0.0753294717788695  Saving model ...
# val Loss: 1.3369 Acc: 51.2000
# Epoch 9/249
# ----------
# train Loss: 1.4132 Acc: 47.9644
# Validation loss decreased (1.336873 --> 1.322353). diff: -0.01451954650878906  Saving model ...
# val Loss: 1.3224 Acc: 51.6200
# Epoch 10/249
# ----------
# train Loss: 1.3704 Acc: 49.8889
# Validation loss decreased (1.322353 --> 1.299635). diff: -0.02271798782348644  Saving model ...
# val Loss: 1.2996 Acc: 52.9600
# Epoch 11/249
# ----------
# train Loss: 1.3296 Acc: 51.5333
# Validation loss decreased (1.299635 --> 1.222857). diff: -0.0767785091400146  Saving model ...
# val Loss: 1.2229 Acc: 55.6200
# Epoch 12/249
# ----------
# train Loss: 1.2904 Acc: 53.1489
# Validation loss decreased (1.222857 --> 1.208681). diff: -0.014175104904174729  Saving model ...
# val Loss: 1.2087 Acc: 55.9600
# Epoch 13/249
# ----------
# train Loss: 1.2577 Acc: 54.3244
# Validation loss decreased (1.208681 --> 1.182096). diff: -0.026584972572326615  Saving model ...
# val Loss: 1.1821 Acc: 56.8600
# Epoch 14/249
# ----------
# train Loss: 1.2265 Acc: 55.8022
# Validation loss decreased (1.182096 --> 1.136900). diff: -0.04519615478515626  Saving model ...
# val Loss: 1.1369 Acc: 59.3000
# Epoch 15/249
# ----------
# train Loss: 1.2021 Acc: 56.8244
# Validation loss decreased (1.136900 --> 1.102579). diff: -0.034321662902832006  Saving model ...
# val Loss: 1.1026 Acc: 59.7600
# Epoch 16/249
# ----------
# train Loss: 1.1702 Acc: 58.0733
# Validation loss decreased (1.102579 --> 1.091080). diff: -0.0114989652633668  Saving model ...
# val Loss: 1.0911 Acc: 60.0000
# Epoch 17/249
# ----------
# train Loss: 1.1476 Acc: 59.2533
# Validation loss decreased (1.091080 --> 1.064279). diff: -0.026800514698028577  Saving model ...
# val Loss: 1.0643 Acc: 61.3200
# Epoch 18/249
# ----------
# train Loss: 1.1251 Acc: 60.0400
# Validation loss decreased (1.064279 --> 1.053146). diff: -0.011132719993591333  Saving model ...
# val Loss: 1.0531 Acc: 62.3000
# Epoch 19/249
# ----------
# train Loss: 1.0926 Acc: 61.1089
# Validation loss decreased (1.053146 --> 1.027967). diff: -0.025179805278777945  Saving model ...
# val Loss: 1.0280 Acc: 63.1200
# Epoch 20/249
# ----------
# train Loss: 1.0709 Acc: 61.5556
# Validation loss decreased (1.027967 --> 1.002291). diff: -0.02567588596344006  Saving model ...
# val Loss: 1.0023 Acc: 63.7200
# Epoch 21/249
# ----------
# train Loss: 1.0557 Acc: 62.3467
# Validation loss decreased (1.002291 --> 0.975467). diff: -0.026823371315002453  Saving model ...
# val Loss: 0.9755 Acc: 65.0600
# Epoch 22/249
# ----------
# train Loss: 1.0365 Acc: 63.2244
# EarlyStopping counter: 1 out of 200
# val Loss: 0.9886 Acc: 64.3600
# Epoch 23/249
# ----------
# train Loss: 1.0174 Acc: 63.8156
# Validation loss decreased (0.975467 --> 0.949377). diff: -0.026090400218963583  Saving model ...
# val Loss: 0.9494 Acc: 65.6400
# Epoch 24/249
# ----------
# train Loss: 1.0026 Acc: 64.2756
# Validation loss decreased (0.949377 --> 0.938830). diff: -0.010546839237213113  Saving model ...
# val Loss: 0.9388 Acc: 66.3400
# Epoch 25/249
# ----------
# train Loss: 0.9811 Acc: 65.0978
# EarlyStopping counter: 1 out of 200
# val Loss: 0.9416 Acc: 65.8800
# Epoch 26/249
# ----------
# train Loss: 0.9722 Acc: 65.5800
# Validation loss decreased (0.938830 --> 0.906653). diff: -0.03217693443298342  Saving model ...
# val Loss: 0.9067 Acc: 67.2200
# Epoch 27/249
# ----------
# train Loss: 0.9598 Acc: 65.9267
# EarlyStopping counter: 1 out of 200
# val Loss: 0.9356 Acc: 66.0600
# Epoch 28/249
# ----------
# train Loss: 0.9507 Acc: 66.3533
# Validation loss decreased (0.906653 --> 0.897599). diff: -0.009053869915008561  Saving model ...
# val Loss: 0.8976 Acc: 67.3400
# Epoch 29/249
# ----------
# train Loss: 0.9337 Acc: 67.1844
# EarlyStopping counter: 1 out of 200
# val Loss: 0.9003 Acc: 67.5800
# Epoch 30/249
# ----------
# train Loss: 0.9195 Acc: 67.5422
# Validation loss decreased (0.897599 --> 0.890325). diff: -0.007273856544494639  Saving model ...
# val Loss: 0.8903 Acc: 68.1000
# Epoch 31/249
# ----------
# train Loss: 0.9126 Acc: 67.8111
# Validation loss decreased (0.890325 --> 0.881480). diff: -0.008845352840423537  Saving model ...
# val Loss: 0.8815 Acc: 68.5000
# Epoch 32/249
# ----------
# train Loss: 0.8997 Acc: 68.2889
# Validation loss decreased (0.881480 --> 0.870216). diff: -0.011264062690734877  Saving model ...
# val Loss: 0.8702 Acc: 68.8000
# Epoch 33/249
# ----------
# train Loss: 0.8960 Acc: 68.5622
# Validation loss decreased (0.870216 --> 0.853346). diff: -0.01686978101730352  Saving model ...
# val Loss: 0.8533 Acc: 69.5800
# Epoch 34/249
# ----------
# train Loss: 0.8813 Acc: 68.7844
# Validation loss decreased (0.853346 --> 0.847684). diff: -0.005662560749053913  Saving model ...
# val Loss: 0.8477 Acc: 70.1800
# Epoch 35/249
# ----------
# train Loss: 0.8714 Acc: 69.3200
# Validation loss decreased (0.847684 --> 0.844433). diff: -0.003250871276855527  Saving model ...
# val Loss: 0.8444 Acc: 69.9600
# Epoch 36/249
# ----------
# train Loss: 0.8647 Acc: 69.8200
# Validation loss decreased (0.844433 --> 0.841223). diff: -0.003210303592681818  Saving model ...
# val Loss: 0.8412 Acc: 69.8000
# Epoch 37/249
# ----------
# train Loss: 0.8597 Acc: 69.9622
# Validation loss decreased (0.841223 --> 0.837599). diff: -0.0036239059448242017  Saving model ...
# val Loss: 0.8376 Acc: 70.5400
# Epoch 38/249
# ----------
# train Loss: 0.8401 Acc: 70.4889
# Validation loss decreased (0.837599 --> 0.815092). diff: -0.02250700702667241  Saving model ...
# val Loss: 0.8151 Acc: 71.2400
# Epoch 39/249
# ----------
# train Loss: 0.8359 Acc: 70.7556
# EarlyStopping counter: 1 out of 200
# val Loss: 0.8316 Acc: 70.6400
# Epoch 40/249
# ----------
# train Loss: 0.8321 Acc: 70.8000
# Validation loss decreased (0.815092 --> 0.811456). diff: -0.003635484981536874  Saving model ...
# val Loss: 0.8115 Acc: 71.1600
# Epoch 41/249
# ----------
# train Loss: 0.8216 Acc: 71.1911
# EarlyStopping counter: 1 out of 200
# val Loss: 0.8289 Acc: 70.4400
# Epoch 42/249
# ----------
# train Loss: 0.8097 Acc: 71.6756
# Validation loss decreased (0.811456 --> 0.798830). diff: -0.01262589588165286  Saving model ...
# val Loss: 0.7988 Acc: 71.3000
# Epoch 43/249
# ----------
# train Loss: 0.8086 Acc: 71.4778
# Validation loss decreased (0.798830 --> 0.789907). diff: -0.008923565292358382  Saving model ...
# val Loss: 0.7899 Acc: 72.0800
# Epoch 44/249
# ----------
# train Loss: 0.7988 Acc: 72.1178
# Validation loss decreased (0.789907 --> 0.788384). diff: -0.001522500133514404  Saving model ...
# val Loss: 0.7884 Acc: 71.1800
# Epoch 45/249
# ----------
# train Loss: 0.7951 Acc: 72.1133
# Validation loss decreased (0.788384 --> 0.785600). diff: -0.0027844187736510984  Saving model ...
# val Loss: 0.7856 Acc: 72.1800
# Epoch 46/249
# ----------
# train Loss: 0.7919 Acc: 72.3867
# EarlyStopping counter: 1 out of 200
# val Loss: 0.8042 Acc: 71.6400
# Epoch 47/249
# ----------
# train Loss: 0.7838 Acc: 72.5667
# Validation loss decreased (0.785600 --> 0.763921). diff: -0.021679152011871317  Saving model ...
# val Loss: 0.7639 Acc: 73.3200
# Epoch 48/249
# ----------
# train Loss: 0.7709 Acc: 73.0356
# EarlyStopping counter: 1 out of 200
# val Loss: 0.7777 Acc: 72.3600
# Epoch 49/249
# ----------
# train Loss: 0.7686 Acc: 73.2356
# EarlyStopping counter: 2 out of 200
# val Loss: 0.7976 Acc: 71.8200
# Epoch 50/249
# ----------
# train Loss: 0.7488 Acc: 74.1933
# Validation loss decreased (0.763921 --> 0.743152). diff: -0.020768955516815235  Saving model ...
# val Loss: 0.7432 Acc: 73.4800
# Epoch 51/249
# ----------
# train Loss: 0.7375 Acc: 74.4756
# EarlyStopping counter: 1 out of 200
# val Loss: 0.7504 Acc: 73.1800
# Epoch 52/249
# ----------
# train Loss: 0.7379 Acc: 74.4356
# Validation loss decreased (0.743152 --> 0.737150). diff: -0.006001346874237035  Saving model ...
# val Loss: 0.7372 Acc: 74.1200
# Epoch 53/249
# ----------
# EarlyStopping counter: 4 out of 200
# val Loss: 0.6057 Acc: 79.5600
# Epoch 241/249
# ----------
# train Loss: 0.5013 Acc: 82.7844
# EarlyStopping counter: 5 out of 200
# val Loss: 0.6248 Acc: 79.1000
# Epoch 242/249
# ----------
# train Loss: 0.5058 Acc: 82.5889
# EarlyStopping counter: 6 out of 200
# val Loss: 0.6164 Acc: 78.5600
# Epoch 243/249
# ----------
# train Loss: 0.5067 Acc: 82.5422
# EarlyStopping counter: 7 out of 200
# val Loss: 0.6194 Acc: 79.0800
# Epoch 244/249
# ----------
# train Loss: 0.5078 Acc: 82.6644
# EarlyStopping counter: 8 out of 200
# val Loss: 0.6190 Acc: 79.3800
# Epoch 245/249
# ----------
# train Loss: 0.5064 Acc: 82.5511
# EarlyStopping counter: 9 out of 200
# val Loss: 0.6274 Acc: 78.6600
# Epoch 246/249
# ----------
# train Loss: 0.5105 Acc: 82.4422
# EarlyStopping counter: 10 out of 200
# val Loss: 0.6301 Acc: 78.9200
# Epoch 247/249
# ----------
# train Loss: 0.5051 Acc: 82.6244
# EarlyStopping counter: 11 out of 200
# val Loss: 0.6154 Acc: 79.0800
# Epoch 248/249
# ----------
# train Loss: 0.5088 Acc: 82.5333
# EarlyStopping counter: 12 out of 200
# val Loss: 0.6133 Acc: 79.0600
# Epoch 249/249
# ----------
# train Loss: 0.5031 Acc: 82.7711
# EarlyStopping counter: 13 out of 200
# val Loss: 0.6060 Acc: 79.1000

# %%
# save msvt index across layers
with open(f'{net_name}_loss_acc.pkl', 'wb') as f:
    pickle.dump(dict(train_loss = train_loss, val_loss = val_loss, train_acc = train_acc, val_acc = val_acc), f)

# %%
# plot train and validation loss
plt.style.use('default')
plt.plot(train_loss, color= [0.1922,0.2118,0.5843],linestyle='-',linewidth=3,
        alpha=1)
plt.plot(val_loss, color= [0.1922,0.2118,0.5843],linestyle='--',linewidth=3,
        alpha=1)
plt.ylabel('loss',fontsize=16, color='k',fontname='arial')
plt.xlabel('epochs',fontsize=16, color='k',fontname='arial')
plt.tight_layout()
plt.grid(color= [0.8, 0.8, 0.8], linestyle='--', linewidth=1)
xtick = [0, 50, 100, 150, 200,250] 
xticklabel = ['0', '50', '100', '150','200','250'] 
ytick = [0.005, 0.015, 0.025, 0.035] 
yticklabel = ['0.005', '0.015', '0.025', '0.035'] 
plt.xticks(xtick, xticklabel)
plt.yticks(ytick, yticklabel)
plt.box(on=None)

# %%
# plot train and validation accuracies
plt.plot(train_acc, color= [0.1922,0.2118,0.5843],linestyle='-',linewidth=3,
        alpha=1)
plt.plot(val_acc, color= [0.1922,0.2118,0.5843],linestyle='--',linewidth=3,
        alpha=1)
plt.ylabel('accuracy',fontsize=16, color='k',fontname='arial')
plt.xlabel('epochs',fontsize=16, color='k',fontname='arial')
plt.tight_layout()
plt.grid(color= [0.8, 0.8, 0.8], linestyle='--', linewidth=1)
xtick = [0, 50, 100, 150, 200, 250] 
xticklabel = ['0', '50', '100', '150','200', '250'] 
ytick = [20, 40, 60, 80, 100] 
yticklabel = ['20', '40', '60', '80', '100'] 
plt.xticks(xtick, xticklabel)
plt.yticks(ytick, yticklabel)
plt.box(on=None)

# %%
# Save model
torch.save(net.state_dict(), PATH)

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _,predicted = torch.max(outputs.data,1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
print('Accuracy of the network on test dataset: %d %%' % (100 * correct / total))
# Out:
# Accuracy of the network on test dataset: 81 %

# %% [markdown]
# ### Run the trained model on our stimulus set

# %%
# Load model
net.load_state_dict(torch.load(PATH))
net.eval()
# Out:
# Net(
#   (conv1_1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv1_2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv2_2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=3200, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
#   (drop): Dropout(p=0.5, inplace=False)
#   (batch1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def msvt_index(input):
    """
    mirror-symmetric viewpoint tuning index function
    input: RDM, views x views
    ouput: mirror-symmetric viewpoint tuning index
    """

    input_hflipped = np.fliplr(input)

    # index of central column
    indx = np.ceil(len(input)/2) - 1

    # remove central column
    input = np.delete(input, int(indx), axis=1)
    input_hflipped = np.delete(input_hflipped, int(indx), axis=1)

    # mirror symmetric viewpoint tuning index
    tmp = np.corrcoef(input.flatten(),input_hflipped.flatten())
    output = tmp[0,1]
    return output

# %%
name_layers = []
slayer = []
for name, layer in net.named_modules():
        if 'conv' in name or 'fc' in name:
            name_layers.append(name)
            slayer.append(layer)

# %%
# get activation function
activation = {}
def get_activation(name):
    def hook(net, input, output):
        if hasattr(output,'detach'):
            activation[name] = output.detach()
        else:
            activation[name] = output[0][0]            

    return hook

# image transforms:<
# original
transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261]), 
])

# %%
# layer output in response to image
msvt_index_values = [[] for i in range(len(slayer))]
rdms = [[] for i in range(len(slayer))]
with torch.no_grad():
    for i_layer in range (0,len(slayer)):
            imgs_res = []
            imgs_res_zscored = []
            slayer[i_layer].register_forward_hook(get_activation(name_layers[i_layer]))

            for i_image in range(len(imgs)):

                img = imgs[i_image]
                img = np.stack((img,img,img), axis=2)
                img = Image.fromarray(img)
                input = transform(img)
                input = torch.unsqueeze(input,axis=0)

                _ = net(input.to(device))
                res = activation[name_layers[i_layer]]
                # relu
                res = torch.max(res, torch.zeros_like(res))

                tmp = res.flatten().squeeze().cpu().numpy()
                imgs_res.append(tmp)
            
            imgs_res_zscored = stats.zscore(imgs_res) # np.array(imgs_res, dtype='float16')
            imgs_res_zscored = imgs_res_zscored[:,~np.isnan(imgs_res_zscored).any(axis=0)] # remove nan columns
            print(imgs_res_zscored.shape)
            for i_catg in range(0,ncatg):
                catg_idx = np.arange(i_catg * (nview*nexemplar), (i_catg+1) * (nview*nexemplar),1)
                for i_exemplar in range(0,nexemplar):
                    exemplar_idx = catg_idx[np.arange(i_exemplar, (nview * nexemplar), nexemplar)]
                    # compute dissimilarity matrix
                    obj_res_zscored = imgs_res_zscored[exemplar_idx]
                    RDM = 1 - np.corrcoef(obj_res_zscored)
                    msvt_index_values[i_layer].append(msvt_index(RDM))
                    rdms[i_layer].append(RDM)
            print(f'layer:{i_layer}')
# Out:
# (2025, 23570)
# layer:0
# (2025, 22741)
# layer:1
# (2025, 9063)
# layer:2
# (2025, 12764)
# layer:3
# (2025, 251)
# layer:4
# (2025, 256)
# layer:5
# (2025, 10)
# layer:6

# %%
# save msvt index across layers
with open(f'{msvt_dir}msvt_index_{net_name}.pkl', 'wb') as f:
    pickle.dump(dict(msvt = msvt_index_values, name = name_layers, rdms = rdms), f)
